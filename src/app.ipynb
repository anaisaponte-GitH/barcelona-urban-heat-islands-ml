# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
# Load the dataset
df_bcn = pd.read_csv('data/barcelona_2015_2026.csv', sep=',', engine='python')
df_temp = pd.read_csv('data/barcelona_temp_2020_2025_test.csv', sep=',', engine='python')
df_bcn_migracion = pd.read_csv('data/censph16401sec2025.csv', sep=',', engine='python')

# %%
df_bcn.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 133903 entries, 0 to 133902
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ndvi         133903 non-null  float64
#  1   ndbi         133903 non-null  float64
#  2   lst_celsius  133903 non-null  float64
#  3   elevation    133903 non-null  int64
#  4   longitude    133903 non-null  float64
#  5   latitude     133903 non-null  float64
#  6   fecha        133903 non-null  str
# dtypes: float64(5), int64(1), str(1)
# memory usage: 7.2 MB

# %%
df_bcn.head()
# Out:
#        ndvi      ndbi  lst_celsius  elevation  longitude   latitude  \
# 0  0.104949  0.141052    36.740617        187   2.153994  41.421864
# 1  0.275537  0.061476    34.693557          7   2.085892  41.334321
# 2  0.083277  0.167822    37.000677         58   2.118558  41.375535
# 3  0.725166 -0.147893    29.298013        272   2.098252  41.446837
# 4 -0.032787 -0.113208    38.393443          0   2.254149  41.404057
#
#         fecha
# 0  2016-07-17
# 1  2016-07-17
# 2  2016-07-17
# 3  2016-07-17
# 4  2016-07-17

# %%
#standarizar ndvi y ndvi para que sean de 0 a 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_bcn[['ndvi', 'ndbi']] = scaler.fit_transform(df_bcn[['ndvi', 'ndbi']])

# %%
#graficar correlación de pearson entre ndvi y ndbi
pearson_corr = df_bcn['ndvi'].corr(df_bcn['ndbi'])
print(f'Correlación de Pearson entre NDVI y NDBI: {pearson_corr}')
# Out:
# Correlación de Pearson entre NDVI y NDBI: -0.2343841580040441

# %% [markdown]
# PIPELINE

# %%
df_temp['fecha'] = pd.to_datetime(df_temp['fecha'])
df_bcn['fecha'] = pd.to_datetime(df_bcn['fecha'])

# %%
fechas_comunes = set(df_temp['fecha']).intersection(
    set(df_bcn['fecha'])
)

df_temp = df_temp[df_temp['fecha'].isin(fechas_comunes)]
df_bcn = df_bcn[df_bcn['fecha'].isin(fechas_comunes)]

# %%
gdf_temp = gpd.GeoDataFrame(
    df_temp,
    geometry=gpd.points_from_xy(
        df_temp.longitude,
        df_temp.latitude
    ),
    crs='EPSG:4326'
)

gdf_bcn = gpd.GeoDataFrame(
    df_bcn,
    geometry=gpd.points_from_xy(
        df_bcn.longitude,
        df_bcn.latitude
    ),
    crs='EPSG:4326'
)

# %%
gdf_temp = gdf_temp.to_crs(32631)
gdf_bcn = gdf_bcn.to_crs(32631)

# %%
merged_list = []

for fecha in fechas_comunes:

    temp_day = gdf_temp[gdf_temp['fecha'] == fecha]

    bcn_day = gdf_bcn[gdf_bcn['fecha'] == fecha]

    merged_day = gpd.sjoin_nearest(
        bcn_day,
        temp_day[
            [
                'lst_day_c',
                'lst_night_c',
                'geometry'
            ]
        ],
        how='left',
        distance_col='dist_m'
    )

    merged_list.append(merged_day)

dataset_final = pd.concat(
    merged_list,
    ignore_index=True
)

# %%
dataset_final.head()
# Out:
#        ndvi      ndbi  lst_celsius  elevation  longitude   latitude  \
# 0  0.488996  0.445247    38.264105        187   2.153994  41.421864
# 1  0.671332  0.495323    33.888025          7   2.085892  41.334321
# 2  0.529880  0.585756    37.282869         58   2.118558  41.375535
# 3  0.526199  0.485032    37.371225        272   2.098252  41.446837
# 4  0.473934  0.442897    38.625592          0   2.254149  41.404057
#
#        fecha                        geometry  index_right  lst_day_c  \
# 0 2024-08-04  POINT (429304.881 4585935.047)        22204      35.27
# 1 2024-08-04  POINT (423511.433 4576273.929)        22275      36.53
# 2 2024-08-04  POINT (426291.341 4580821.115)        22245      36.57
# 3 2024-08-04   POINT (424675.713 4588754.47)        22194      31.13
# 4 2024-08-04  POINT (437657.155 4583881.193)        22209      36.85
#
#    lst_night_c       dist_m
# 0        25.83   254.847100
# 1        25.63   259.206483
# 2        26.71   480.235785
# 3        23.73  2957.398286
# 4        27.05  4151.343285

# %%
dataset_final['dist_m'].describe()
# Out:
# count    12230.000000
# mean      1679.086824
# std       1896.503448
# min          9.205649
# 25%        404.440213
# 50%        654.751781
# 75%       2625.359725
# max       9413.432726
# Name: dist_m, dtype: float64

# %% [markdown]
# LIMPIEZA

# %%
dataset_final = dataset_final.drop(
    columns=[
        'geometry',
        'index_right'
    ],
    errors='ignore'
)

# %%
dataset_final.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12230 entries, 0 to 12229
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ndvi         12230 non-null  float64
#  1   ndbi         12230 non-null  float64
#  2   lst_celsius  12230 non-null  float64
#  3   elevation    12230 non-null  int64
#  4   longitude    12230 non-null  float64
#  5   latitude     12230 non-null  float64
#  6   fecha        12230 non-null  datetime64[us]
#  7   lst_day_c    12230 non-null  float64
#  8   lst_night_c  12230 non-null  float64
#  9   dist_m       12230 non-null  float64
# dtypes: datetime64[us](1), float64(8), int64(1)
# memory usage: 955.6 KB

# %%
#MAtriz de correlación entre ndvi, ndbi, lst_day_c y lst_night_c
corr_matrix = dataset_final[
    [
        'ndvi',
        'ndbi',
        'lst_day_c',
        'lst_night_c'
    ]
].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
#R2 de pearson entre ndvi y lst_day_c. y entre ndbi y lst_day_c
pearson_corr_ndvi_lst_day = dataset_final['ndvi'].corr(dataset_final['lst_day_c'])
print(f'Correlación de Pearson entre NDVI y LST Day: {pearson_corr_ndvi_lst_day}')

pearson_corr_ndbi_lst_day = dataset_final['ndbi'].corr(dataset_final['lst_day_c'])
print(f'Correlación de Pearson entre NDBI y LST Day: {pearson_corr_ndbi_lst_day}')
# Out:
# Correlación de Pearson entre NDVI y LST Day: 0.11534732634015482
# Correlación de Pearson entre NDBI y LST Day: 0.15556245555965362

# %% [markdown]
# SPLIT + TRAIN

# %%
df_temp.groupby('fecha').size().describe()
# Out:
# count     24.000000
# mean     106.083333
# std       20.216043
# min       27.000000
# 25%      100.500000
# 50%      112.500000
# 75%      118.000000
# max      125.000000
# dtype: float64

# %%
df_temp.groupby('fecha').size().sort_values().head(20)
# Out:
# fecha
# 2023-09-14     27
# 2023-05-17     86
# 2023-08-05     91
# 2024-08-04     91
# 2025-10-08     93
# 2020-08-20     93
# 2022-08-05    103
# 2020-02-02    104
# 2024-06-25    109
# 2025-01-01    110
# 2021-12-03    112
# 2023-04-07    112
# 2022-01-17    113
# 2022-12-03    113
# 2022-05-17    114
# 2021-01-17    116
# 2023-10-24    116
# 2020-07-11    118
# 2021-10-24    118
# 2025-11-09    119
# dtype: int64

# %% [markdown]
# Filtar por imágenes con suficientes valores válidos

# %%
counts = df_temp.groupby('fecha').size()

fechas_validas = counts[counts >= 50].index

df_temp_filtered = df_temp[df_temp['fecha'].isin(fechas_validas)]
df_bcn_filtered = df_bcn[df_bcn['fecha'].isin(fechas_validas)]

# %%
print(f'Número de fechas válidas: {len(fechas_validas)}')
# Out:
# Número de fechas válidas: 23

# %% [markdown]
# GRID 1 km

# %%
import geopandas as gpd
import pandas as pd

gdf_bcn = gpd.GeoDataFrame(
    df_bcn,
    geometry=gpd.points_from_xy(
        df_bcn.longitude,
        df_bcn.latitude
    ),
    crs='EPSG:4326'
)

gdf_temp = gpd.GeoDataFrame(
    df_temp,
    geometry=gpd.points_from_xy(
        df_temp.longitude,
        df_temp.latitude
    ),
    crs='EPSG:4326'
)

# %%
gdf_bcn = gdf_bcn.to_crs(32631)
gdf_temp = gdf_temp.to_crs(32631)

# %%
gdf_bcn['x'] = gdf_bcn.geometry.x
gdf_bcn['y'] = gdf_bcn.geometry.y

gdf_temp['x'] = gdf_temp.geometry.x
gdf_temp['y'] = gdf_temp.geometry.y

# %%
GRID_SIZE = 1000

gdf_bcn['grid_x'] = (
    gdf_bcn['x'] // GRID_SIZE
).astype(int)

gdf_bcn['grid_y'] = (
    gdf_bcn['y'] // GRID_SIZE
).astype(int)

gdf_bcn['grid_id'] = (
    gdf_bcn['grid_x'].astype(str)
    + '_'
    + gdf_bcn['grid_y'].astype(str)
)

# %%
gdf_temp['grid_x'] = (
    gdf_temp['x'] // GRID_SIZE
).astype(int)

gdf_temp['grid_y'] = (
    gdf_temp['y'] // GRID_SIZE
).astype(int)

gdf_temp['grid_id'] = (
    gdf_temp['grid_x'].astype(str)
    + '_'
    + gdf_temp['grid_y'].astype(str)
)

# %%
sentinel_agg = (
    gdf_bcn
    .groupby(['fecha', 'grid_id'])
    .agg({
        'ndvi': 'mean',
        'ndbi': 'mean',
        'elevation': 'mean',
        'latitude': 'mean',
        'longitude': 'mean'
    })
    .reset_index()
)

# %%
modis_agg = (
    gdf_temp
    .groupby(['fecha', 'grid_id'])
    .agg({
        'lst_day_c': 'mean',
        'lst_night_c': 'mean'
    })
    .reset_index()
)

# %%
#MERGE
dataset_final = pd.merge(
    sentinel_agg,
    modis_agg,
    on=['fecha', 'grid_id'],
    how='inner'
)

# %%
dataset_final.shape
# Out:
# (2247, 9)

# %%
dataset_final.groupby('fecha').size().describe()
# Out:
# count     24.000000
# mean      93.625000
# std       18.478689
# min       21.000000
# 25%       88.750000
# 50%       99.000000
# 75%      104.250000
# max      112.000000
# dtype: float64

# %%
dataset_final['fecha'] = pd.to_datetime(
    dataset_final['fecha']
)

dataset_final['month'] = (
    dataset_final['fecha'].dt.month
)

dataset_final['dayofyear'] = (
    dataset_final['fecha'].dt.dayofyear
)

dataset_final['year'] = (
    dataset_final['fecha'].dt.year
)

# %% [markdown]
# VALIDEZ

# %%
dataset_final.isna().mean()
# Out:
# fecha          0.0
# grid_id        0.0
# ndvi           0.0
# ndbi           0.0
# elevation      0.0
# latitude       0.0
# longitude      0.0
# lst_day_c      0.0
# lst_night_c    0.0
# month          0.0
# dayofyear      0.0
# year           0.0
# dtype: float64

# %%
dataset_final['lst_day_c'].describe()
# Out:
# count    2247.000000
# mean       25.096044
# std         9.302978
# min         8.590000
# 25%        16.310000
# 50%        24.250000
# 75%        34.230000
# max        41.330000
# Name: lst_day_c, dtype: float64

# %%
#Crear columna de anomalia términa para lst_day_c restando la media mensual de lst_day_c a cada valor de lst_day_c
dataset_final['lst_day_c_anomaly'] = (dataset_final['lst_day_c'] - dataset_final['lst_day_c'].mean())

# %%
#media de temperatura 
dataset_final['lst_day_c'].mean()
# Out:
# np.float64(25.09604361370719)

# %%
#Crear columna de anomalia térmica para lst_night_c restando la media mensual de lst_night_c a cada valor de lst_night_c
dataset_final['lst_night_c_anomaly'] = (dataset_final['lst_night_c'] - dataset_final['lst_night_c'].mean())

# %%
#histograma de lst_night_c_anomaly
sns.histplot(dataset_final['lst_night_c_anomaly'], bins=30, kde=True)
# Out:
# <Axes: xlabel='lst_night_c_anomaly', ylabel='Count'>

# %%
#histograma de lst_day_c_anomaly
sns.histplot(dataset_final['lst_day_c_anomaly'], bins=30, kde=True)
# Out:
# <Axes: xlabel='lst_day_c_anomaly', ylabel='Count'>

# %%
#Clasificar lst_day_c_anomaly en 3 categorias: baja, media y alta
dataset_final['lst_day_c_anomaly_cat'] = pd.cut(dataset_final['lst_day_c_anomaly'], bins=3, labels=['baja', 'media', 'alta'])

# %%
dataset_final['lst_day_c_anomaly_cat'].value_counts()
# Out:
# lst_day_c_anomaly_cat
# alta     894
# baja     728
# media    625
# Name: count, dtype: int64

# %% [markdown]
# RANDOM FOREST DE PRUEBA

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Prepare Features and Target
features = ['ndvi', 'ndbi', 'elevation', 'latitude', 'longitude']
target = 'lst_day_c_anomaly_cat'

# Ensure the categorical column is ready (handled in your previous steps)
# Using the same temporal split defined in your notebook
train = dataset_final[dataset_final['year'] <= 2023]
test = dataset_final[dataset_final['year'] >= 2024]

X_train = train[features]
y_train = train[target]
X_test = test[features]
y_test = test[target]

# 2. Initialize and Train the Classifier
rf_classifier = RandomForestClassifier(
    n_estimators=300,
    max_depth=20,
    min_samples_leaf=5,
    random_state=42,
    n_jobs=-1,
    class_weight='balanced' # Handles potential imbalance in anomaly categories
)

rf_classifier.fit(X_train, y_train)

# 3. Make Predictions
y_pred = rf_classifier.predict(X_test)

# 4. Evaluation
print(f"Accuracy Score: {accuracy_score(y_test, y_pred):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# 5. Visualizing Feature Importance
importances = pd.Series(rf_classifier.feature_importances_, index=features).sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=importances, y=importances.index, palette='viridis')
plt.title('Feature Importance for Heat Anomaly Classification')
plt.show()

# 6. Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred, labels=['baja', 'media', 'alta'])
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['baja', 'media', 'alta'], yticklabels=['baja', 'media', 'alta'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix: Anomaly Class')
plt.show()
# Out:
# Accuracy Score: 0.4837
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         alta       0.51      0.65      0.57       237
#         baja       0.50      0.47      0.48       219
#        media       0.42      0.32      0.36       220
#
#     accuracy                           0.48       676
#    macro avg       0.48      0.48      0.47       676
# weighted avg       0.48      0.48      0.47       676
# /tmp/ipykernel_3221/43415396.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importances, y=importances.index, palette='viridis')

# %%
#Distribución visual de fechas en dataset_final
dataset_final['fecha'].value_counts().sort_index().plot(kind='line')
plt.xlabel('Fecha')
# Out:
# Text(0.5, 0, 'Fecha')

# %%
#Timeseries que muestre la evolución de lst_day_c a lo largo del tiempo
dataset_final.groupby('fecha')['lst_day_c'].mean().plot(kind='line')
# Out:
# <Axes: xlabel='fecha'>

# %%
train = dataset_final[
    dataset_final['year'] <= 2023
]

test = dataset_final[
    dataset_final['year'] >= 2024
]

# %%
features = [
    'ndvi',
    'ndbi',
    'elevation',
    'latitude',
    'longitude',
    # 'dayofyear'
]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=20,
    min_samples_leaf=5,
    random_state=42,
    n_jobs=-1
)

# %%
rf.fit(
    train[features],
    train['lst_day_c']
)
# Out:
# RandomForestRegressor(max_depth=20, min_samples_leaf=5, n_estimators=300,
#                       n_jobs=-1, random_state=42)

# %%
preds = rf.predict(test[features])

# %%
print(test['lst_day_c'])
# Out:
# 1571    31.01
# 1572    30.99
# 1573    31.21
# 1574    31.37
# 1575    31.91
#         ...
# 2242    15.99
# 2243    16.53
# 2244    14.99
# 2245    16.01
# 2246    15.97
# Name: lst_day_c, Length: 676, dtype: float64

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)

import numpy as np

mse = mean_squared_error(
    test['lst_day_c'],
    preds
)

rmse = np.sqrt(mse)

print('R2:', r2_score(test['lst_day_c'], preds))
print('MAE:', mean_absolute_error(test['lst_day_c'], preds))
print('RMSE:', rmse)
# Out:
# R2: 0.13748424396485226
# MAE: 6.206037908271912
# RMSE: 7.578135701177515

# %%
import pandas as pd

importance = pd.Series(
    rf.feature_importances_,
    index=features
).sort_values(ascending=False)

print(importance)
# Out:
# ndbi         0.351911
# ndvi         0.302538
# longitude    0.130167
# latitude     0.113335
# elevation    0.102048
# dtype: float64

# %%
residuals = test['lst_day_c'] - preds
sns.scatterplot(x=preds, y=residuals)
plt.axhline(0, color='red', linestyle='--')

# %% [markdown]
# JOIN_GEO

# %%
gdf_bcn_ndvi = gpd.GeoDataFrame(
    df_bcn,
    geometry=gpd.points_from_xy(
        df_bcn.longitude,
        df_bcn.latitude
    ),
    crs="EPSG:4326"
)

gdf_bcn_ndvi = gdf_bcn_ndvi.to_crs(secciones.crs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 10
#       1 gdf_bcn_ndvi = gpd.GeoDataFrame(
#       2     df_bcn,
#       3     geometry=gpd.points_from_xy(
#    (...)      7     crs="EPSG:4326"
#       8 )
# ---> 10 gdf_bcn_ndvi = gdf_bcn_ndvi.to_crs(secciones.crs)
#
# NameError: name 'secciones' is not defined

# %%
gdf_joined = gpd.sjoin(
    gdf_bcn_ndvi,
    secciones_bcn,
    how="inner",
    predicate="within"
)

# %%
sentinel_agg = (
    gdf_joined
    .groupby(['CUSEC'])
    .agg({
        'ndvi': 'mean',
        'ndbi': 'mean',
        'elevation': 'mean',
        'latitude': 'mean',
        'longitude': 'mean'
    })
    .reset_index()
)

# %%
print(sentinel_agg.head())
print(sentinel_agg.shape)
sentinel_agg.info()
